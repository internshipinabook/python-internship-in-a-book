# %% [markdown]
# <a href="https://colab.research.google.com/github/internshipinabook/python-internship-in-a-book/blob/main/notebooks/week2_lists_loops_STARTER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ── Colab setup (skip if running locally) ──────────────────────
import os
if not os.path.exists('requirements.txt'):
    # !git clone https://github.com/internshipinabook/python-internship-in-a-book.git book
    # %cd book
    # !pip install -r requirements.txt -q
    print('Colab setup complete ✅')
else:
    print('Running locally ✅')

# %% [markdown]
# # Week 2 — Lists, Loops, and Decisions
# ### The Python Internship | Meridian Consulting
#
# > **STARTER notebook.** Work Monday to Friday in order.
#
# The Python Book 0 of 9 in the InternshipInABook™ Series
#
# This repository contains the practical exercises from the book.
#
# 📖 Complete internship experience:
#
# Workplace scenarios Mentor guidance Reflection exercises Portfolio checkpoints Capstone projects 👉 Get the complete book: https://selar.com/al990ay7ux
#
# 🚀 Start Here Welcome to The Python Internship.
#
# If you are new to the InternshipInABook™ Series:
#
# Run this setup notebook. Complete Week 1. Follow the weekly internship schedule. Build your portfolio. Complete the capstone project. 🔗 Repository: https://github.com/internshipinabook/python-internship-in-a-book
#
# Run every cell top to bottom. Each cell prints ✅ if everything is working or ❌ with a fix instruction. Complete every fix before moving to Week 1.
#
# ---

# %% [markdown]
# <a href="https://colab.research.google.com/github/internshipinabook/python-internship-in-a-book/blob/main/notebooks/week2_lists_loops_STARTER.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>&nbsp;&nbsp;
# <a href="https://github.com/InternshipInABook/book0-python/blob/main/notebooks/week2/week2_lists_loops_STARTER.ipynb">
#   <img src="https://img.shields.io/badge/View%20on-GitHub-181717?logo=github" alt="View on GitHub"/>
# </a>
#
# ---
#
# ## 🖥️ How to Run This Notebook
#
# | Platform | Instructions |
# |----------|-------------|
# | **Google Colab** | Click the badge above — free, no setup needed |
# | **Local Jupyter** | `pip install -r requirements.txt` then `jupyter lab` |
# | **VS Code** | Open `.ipynb` with the Jupyter extension installed |
# | **GitHub** | Click "View on GitHub" above for a read-only preview |
#
# > **STARTER notebook** — Complete the `# YOUR CODE HERE` cells. Check the SOLUTION notebook if stuck.

# %%
# ── PLATFORM SETUP ───────────────────────────────────────────────────────────
# Run this cell first. It installs missing libraries in Google Colab.
# In a local environment, skip it if requirements.txt is already installed.

import sys, subprocess

IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
    print("📦 Google Colab detected — installing libraries...")
    subprocess.run([sys.executable, '-m', 'pip', 'install', '-q',
                    'pandas>=1.5', 'numpy>=1.23', 'matplotlib>=3.6',
                    'seaborn>=0.12', 'scikit-learn>=1.2'], check=True)
    print("✅ Libraries installed.")
else:
    print("💻 Running locally.")
    print("   If you see ImportError below, run: pip install -r requirements.txt")

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## This week covers
#
# Lists and indexing | List methods | if/elif/else | for loops | while loops | break and continue | The accumulator pattern
#
# ---

# %% [markdown]
# ## MONDAY -- Lists
#
# A list holds multiple values under one name, inside square brackets.
# Indexes start at **zero** -- the first item is at index 0, not index 1.
#
# ---

# %% [markdown]
# ### Example 1 -- Creating a list and accessing items

# %%
menu_items = [
    "Jollof Rice",   # index 0 -- the FIRST item
    "Pounded Yam",   # index 1
    "Egusi Soup",    # index 2
    "Pepper Soup"    # index 3 -- the LAST item in this 4-item list
]
print(len(menu_items))    # 4
print(menu_items[0])      # Jollof Rice
print(menu_items[3])      # Pepper Soup
print(menu_items[-1])     # Pepper Soup -- -1 is always the last item
print(menu_items[-2])     # Egusi Soup  -- second from the end

# %% [markdown]
# ### Example 2 -- Slicing (start included, stop excluded)

# %%
menu_items = ["Jollof Rice","Pounded Yam","Egusi Soup","Pepper Soup","Spring Rolls","Chapman"]
print(menu_items[0:3])   # indexes 0,1,2 -- stop 3 is NOT included
print(menu_items[:3])    # same as [0:3]
print(menu_items[3:])    # from index 3 to the end
print(menu_items[::2])   # every second item: indexes 0, 2, 4

# %% [markdown]
# ### Example 3 -- Membership and mutability

# %%
menu_items = ["Jollof Rice","Pounded Yam","Egusi Soup"]
print("Jollof Rice" in menu_items)    # True
print("Pizza" in menu_items)          # False
print("Pizza" not in menu_items)      # True
menu_items[1] = "Pounded Yam with Egusi"   # lists are mutable -- change in place
print(menu_items)

# %% [markdown]
# ---
# ## MONDAY EXERCISES
# ---

# %% [markdown]
# ### Exercise 2.1 -- Build the menu list

# %%
menu_items = [
    "Jollof Rice","Pounded Yam","Egusi Soup","Pepper Soup",
    "Spring Rolls","Chapman","Zobo","Fresh Juice",
    "Chin Chin","Puff Puff","Fried Plantain","Beef Suya"
]
print("Total:", ___________)
print("First:", ___________)
print("Last:", ___________)
print("Fifth:", ___________)
# Slice indexes 3,4,5,6 -- expected: ["Pepper Soup","Spring Rolls","Chapman","Zobo"]
print("Slice [3:7]:", ___________)

# %% [markdown]
# ### Exercise 2.2 -- Price list and calculations

# %%
menu_items = ["Jollof Rice","Pounded Yam","Egusi Soup","Pepper Soup",
              "Spring Rolls","Chapman","Zobo","Fresh Juice",
              "Chin Chin","Puff Puff","Fried Plantain","Beef Suya"]
prices = [1800, 2200, 1500, 1200, 900, 600, 400, 700, 500, 450, 800, 1100]

print("Jollof Rice:", ___________)
print("Beef Suya:", ___________)
# Three CHEAPEST -- use sorted(prices) then take the FIRST three [:3]
print("Three cheapest:", ___________)
three_total = prices[0] + prices[1] + prices[2]
print(f"First three total: N{three_total:,}")

# %% [markdown]
# ### Exercise 2.3 -- Index predictions

# %%
menu_items = ["Jollof Rice","Pounded Yam","Egusi Soup"]
# Valid positive indexes: 0, 1, 2
print(menu_items[0])                      # prediction:
print(menu_items[2])                      # prediction:
# print(menu_items[3])                   # uncomment -- what error?
print(menu_items[-1])                     # prediction:
print(menu_items[len(menu_items) - 1])   # prediction: -- the safe pattern

# %% [markdown]
# ### Exercise 2.4 -- Membership check

# %%
menu_items = ["Jollof Rice","Pounded Yam","Egusi Soup","Pepper Soup","Spring Rolls","Chapman"]
orders_to_check = ["Jollof Rice","Pasta","Chapman","Burger","Egusi Soup"]
# For each item, print "on the menu" or "NOT on the menu"
# YOUR CODE HERE

# %% [markdown]
# ---
# ## TUESDAY -- List Methods
#
# Methods are functions attached to objects, called with a dot.
#
# ---

# %% [markdown]
# ### Example 1 -- Adding and removing

# %%
menu_items = ["Jollof Rice","Pounded Yam","Egusi Soup"]
menu_items.append("Pepper Soup")     # adds to the END
print(menu_items)
menu_items.insert(1,"Spring Rolls")  # inserts at position 1
print(menu_items)
menu_items.remove("Spring Rolls")    # removes FIRST occurrence
print(menu_items)
last = menu_items.pop()              # removes and returns last item
print(last, "|", menu_items)

# %% [markdown]
# ### Example 2 -- Sorting and statistics

# %%
prices = [1800, 900, 2200, 600, 1500]
prices.sort()                    # modifies IN PLACE -- original gone
print(prices)
original = [1800, 900, 2200, 600, 1500]
new_sorted = sorted(original)    # returns NEW list -- original unchanged
print(new_sorted)
print(original)                  # still original order
prices2 = [1800,2200,1500,1200,900,600,400,700,500,450,800,1100]
print(sum(prices2), min(prices2), max(prices2))
print(round(sum(prices2)/len(prices2), 2))

# %% [markdown]
# ### Example 3 -- count() and index()

# %%
orders_today = ["Jollof Rice","Chapman","Jollof Rice","Puff Puff","Jollof Rice"]
print(orders_today.count("Jollof Rice"))    # 3
print(orders_today.count("Pepper Soup"))    # 0
menu_items = ["Jollof Rice","Pounded Yam","Egusi Soup","Pepper Soup"]
print(menu_items.index("Egusi Soup"))       # 2
if "Egusi Soup" in menu_items:
    print(menu_items.index("Egusi Soup"))   # safe pattern: check before index()

# %% [markdown]
# ---
# ## TUESDAY EXERCISES
# ---

# %% [markdown]
# ### Exercise 2.5 -- Menu manager

# %%
menu_items = ["Jollof Rice","Pounded Yam","Egusi Soup","Pepper Soup","Chapman"]
# 1. Append "Beef Suya"
# 2. Insert "Spring Rolls" at position 2
# 3. Remove "Pounded Yam"
# 4. Replace "Chapman" with "Zobo" using index()
# 5. Sort alphabetically
# Print the list after each step
# YOUR CODE HERE
print("Final count:", len(menu_items))

# %% [markdown]
# ### Exercise 2.6 -- Order statistics

# %% [markdown]
# > A **set** is a collection with no duplicates. `set(list)` removes repeats; `list(set(...))` converts back. Sets are covered fully in Week 3.

# %%
monday_orders = [
    "Jollof Rice","Chapman","Jollof Rice","Pounded Yam","Pepper Soup",
    "Jollof Rice","Zobo","Chapman","Puff Puff","Jollof Rice","Beef Suya",
    "Chapman","Egusi Soup","Jollof Rice","Spring Rolls"
]
print("Total:", ___________)
print("Jollof Rice:", ___________)
print("Chapman:", ___________)
print("First alpha:", sorted(monday_orders)[0])
print("Last alpha:", sorted(monday_orders)[-1])
unique = sorted(list(set(monday_orders)))
print("Unique:", unique)

# %% [markdown]
# ### Exercise 2.7 -- Parallel lists

# %%
menu_items = ["Jollof Rice","Pounded Yam","Egusi Soup","Pepper Soup","Spring Rolls","Chapman"]
prices     = [1800, 2200, 1500, 1200, 900, 600]

max_idx = prices.index(max(prices))
print(f"Most expensive: {menu_items[max_idx]} at N{prices[max_idx]:,}")

min_idx = prices.index(min(prices))
print(f"Least expensive: {menu_items[min_idx]} at N{prices[min_idx]:,}")

# Add "Beef Suya" N1,100 -- append to BOTH to stay aligned
# YOUR CODE
print(f"Both same length: {len(menu_items) == len(prices)}")

# %% [markdown]
# ---
# ## WEDNESDAY -- if / elif / else
#
# Indentation marks what belongs inside each block. 4 spaces per level.
#
# ---

# %% [markdown]
# ### Example 1 -- if / else

# %%
order_value = 4500
vip_threshold = 5000
if order_value >= vip_threshold:
    print("VIP -- 15% discount.")
    discount = 0.15
else:
    print("Standard -- no discount.")
    discount = 0.0
print(f"Discount: {discount:.0%}")   # always runs -- outside both blocks

# %% [markdown]
# ### Example 2 -- if / elif / else

# %%
order_value = 7500
if order_value >= 10000:
    discount_rate = 0.20;  tier = "Platinum"
elif order_value >= 5000:
    discount_rate = 0.15;  tier = "Gold"
elif order_value >= 2000:
    discount_rate = 0.10;  tier = "Silver"
else:
    discount_rate = 0.0;   tier = "Standard"
discount_amount = order_value * discount_rate
final_price     = order_value - discount_amount
print(f"Tier: {tier} | Discount: {discount_rate:.0%} | Total: N{final_price:,.2f}")

# %% [markdown]
# ### Example 3 -- Nested if and compound conditions

# %%
is_weekend = True
time_of_day = "Evening"
order_value = 6000
payment = "Card"
valid_pays = ["Cash","Card","Transfer"]
if is_weekend:
    if time_of_day == "Evening":
        print("Weekend evening pricing.")
    else:
        print("Weekend daytime pricing.")
else:
    print("Weekday pricing.")
if order_value >= 5000 and payment in valid_pays:
    print("Large order accepted.")
if order_value < 1000 or payment not in valid_pays:
    print("Rejected.")
else:
    print("Cleared.")

# %% [markdown]
# ---
# ## WEDNESDAY EXERCISES
# ---

# %% [markdown]
# ### Exercise 2.8 -- Order tier classifier

# %%
order_value = 3500    # TEST WITH: 500, 1500, 3500, 7000, 12000
# N10,000+: Platinum 20% | N5,000-9,999: Gold 15%
# N2,000-4,999: Silver 10% | N1,000-1,999: Bronze 5%
# Below N1,000: Rejected
# YOUR CODE -- if/elif/else
# For accepted tiers: print tier, rate, discount amount, final price

# %% [markdown]
# ### Exercise 2.9 -- Restaurant opening hours

# %%
day        = "Wednesday"
hour       = 14    # 14 = 2pm (24-hour)
is_raining = True
weekend_days = ["Saturday","Sunday"]
# Mon-Fri: open 11am-10pm (hours 11-22)
# Sat-Sun: open 9am-11pm  (hours 9-23)
# Raining on weekday: close one hour early
# Print "OPEN" or "CLOSED" with reason
# YOUR CODE HERE

# %% [markdown]
# ### Exercise 2.10 -- Delivery fee (stepped)

# %%
base_fee         = 500
distance_km      = 8
extra_km_rate    = 100
is_peak_hour     = True
has_loyalty_card = False

extra_km = distance_km - 5 if distance_km > 5 else 0
extra_km_charge = extra_km * extra_km_rate
print(f"Step 1 -- Extra distance: N{extra_km_charge}")

fee_before_peak = base_fee + extra_km_charge
print(f"Step 2 -- Before peak: N{fee_before_peak}")

if is_peak_hour:
    fee_after_peak = fee_before_peak * 2
else:
    fee_after_peak = fee_before_peak
print(f"Step 3 -- After peak: N{fee_after_peak}")

if has_loyalty_card:
    final_fee = max(0, fee_after_peak - 200)
else:
    final_fee = fee_after_peak
print(f"Step 4 -- Final fee: N{final_fee}")

# %% [markdown]
# ### Exercise 2.11 -- Indentation traps

# %%
order_value = 5000
# Each snippet has one indentation error.
# Identify the error, explain it, write the corrected version.

# Snippet A:
# if order_value >= 5000:
# print("VIP")    <- fix this

# Snippet B:
# if order_value >= 5000:
#     print("Large")
#   print("Discount")    <- fix this

# Snippet C:
# if order_value >= 5000:
#     discount = 0.15
# else:
#     discount = 0.0
#     print(f"Discount: {discount:.0%}")   <- inside else or outside?

# YOUR CORRECTED VERSIONS BELOW:

# %% [markdown]
# ---
# ## THURSDAY -- Loops
#
# for loops repeat for each item in a collection.
# while loops repeat until a condition changes.
# break exits a loop early. continue skips to the next iteration.
#
# ---

# %% [markdown]
# ### Example 1 -- for loop basics

# %%
orders = [2400, 1800, 900, 3200, 750]
for order in orders:
    print(order)   # order takes each value in turn

for i in range(5):     # 0, 1, 2, 3, 4
    print(i, end=" ")
print()

for i in range(1, 6):  # 1, 2, 3, 4, 5
    print(i, end=" ")
print()

menu_items = ["Jollof Rice","Pounded Yam","Chapman"]
for idx, item in enumerate(menu_items):
    print(f"  {idx + 1}. {item}")

# %% [markdown]
# ### Example 2 -- Accumulator pattern

# %%
orders_today = [2400, 1800, 900, 3200, 750, 4100, 1200]

# Pattern 1: running total -- initialise BEFORE loop, update INSIDE, report AFTER
total = 0
for order in orders_today:
    total += order
print(f"Total: N{total:,}")

# Pattern 2: collect items meeting a condition
high_value = []
for order in orders_today:
    if order >= 2000:
        high_value.append(order)
print(f"High-value: {high_value}")

# Pattern 3: find best/worst -- start with first real value
best  = orders_today[0]
worst = orders_today[0]
for order in orders_today:
    if order > best:  best  = order
    if order < worst: worst = order
print(f"Best: N{best:,} | Worst: N{worst:,}")

# %% [markdown]
# ### Example 3 -- while loops

# %%
# while keeps running as long as the condition is True
counter = 0
while counter < 5:
    print(f"  count: {counter}")
    counter += 1    # MUST change the condition -- or it loops forever
print("Done.")

# while True with break -- runs until break fires
items = []
test_inputs = ["Jollof Rice", "Chapman", "stop"]   # simulated input
for fake_input in test_inputs:    # simulates user typing
    entry = fake_input
    if entry == "stop":
        break
    items.append(entry)
    print(f"  Added: {entry}")
print(f"Items: {items}")

# %% [markdown]
# ### Example 4 -- break and continue

# %%
# break -- exit immediately when found
menu_items = ["Jollof Rice","Pounded Yam","Egusi Soup","Pepper Soup","Chapman"]
target = "Egusi Soup"
for item in menu_items:
    print(f"  Checking: {item}")
    if item == target:
        print(f"  Found! Stopping.")
        break   # Pepper Soup and Chapman never reached

# continue -- skip invalid items
orders = [2400, -50, 1800, 0, 3200, -200, 750]
total = 0
print("\nValid orders:")
for order in orders:
    if order <= 0:
        continue    # skip to next iteration
    total += order
    print(f"  N{order:,}")
print(f"Total: N{total:,}")

# %% [markdown]
# ---
# ## THURSDAY EXERCISES
# ---

# %% [markdown]
# ### Exercise 2.12 -- Menu price table

# %%
menu_items = ["Jollof Rice","Pounded Yam","Egusi Soup","Pepper Soup",
              "Spring Rolls","Chapman","Zobo","Fresh Juice",
              "Chin Chin","Puff Puff","Fried Plantain","Beef Suya"]
prices = [1800, 2200, 1500, 1200, 900, 600, 400, 700, 500, 450, 800, 1100]

# Print a numbered menu using enumerate()
# ==========================================
#   THE GOLDEN FORK - MENU
# ==========================================
#    1. Jollof Rice              N1,800
#    ...
#   12. Beef Suya                N1,100
# ==========================================
# Total: N12,150  |  Average: N1,012.50

# YOUR CODE HERE

# %% [markdown]
# ### Exercise 2.13 -- Weekly revenue analysis

# %%
days    = ["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
amounts = [98500, 87300, 112400, 95600, 143200, 187600, 124800]
# days[i] earned amounts[i]

# 1. Print each day and amount
# 2. Weekly total
# 3. Average daily (round 2dp)
# 4. Days exceeding the average
# 5. Best and worst day

# YOUR CODE HERE

# %% [markdown]
# ### Exercise 2.14 -- Availability checker (for loop)

# %%
menu_items = ["Jollof Rice","Pounded Yam","Egusi Soup","Pepper Soup","Spring Rolls","Chapman"]
available  = [True, True, False, True, True, False]
# Use range(len(menu_items)) to loop through both lists
# Print each item as AVAILABLE or SOLD OUT
# YOUR CODE HERE

# %% [markdown]
# ### Exercise 2.15 -- Order processing loop

# %%
orders = [
    ("Jollof Rice",2), ("Chapman",3), ("Pounded Yam",1),
    ("Pepper Soup",2), ("Puff Puff",4), ("Beef Suya",1),
]
# for item, qty in orders:
menu_names  = ["Jollof Rice","Chapman","Pounded Yam","Pepper Soup","Puff Puff","Beef Suya"]
item_prices = [1800, 600, 2200, 1200, 450, 1100]
# Use: idx = menu_names.index(item); price = item_prices[idx]

grand_total = 0
print(f"{'Item':<20} {'Qty':>4} {'Unit':>12} {'Subtotal':>12}")
print("-" * 52)
for item, qty in orders:
    idx        = menu_names.index(item)
    unit_price = ___________
    subtotal   = ___________
    grand_total += subtotal
    print(f"{item:<20} {qty:>4} N{unit_price:>9,} N{subtotal:>9,}")
print("-" * 52)
print(f"GRAND TOTAL{' '*27}N{grand_total:>9,}")

# %% [markdown]
# ### Exercise 2.16 -- Best and worst sellers

# %%
items      = ["Jollof Rice","Pounded Yam","Egusi Soup","Pepper Soup",
              "Spring Rolls","Chapman","Zobo","Beef Suya"]
sold_count = [45, 23, 18, 31, 12, 38, 29, 27]

# Best seller
best_count = 0
best_item  = ""
for i in range(len(items)):
    if sold_count[i] > best_count:
        best_count = sold_count[i]
        best_item  = items[i]
print(f"Best: {best_item} ({best_count})")

# Worst seller -- start with first real value (avoids float("inf"))
worst_count = sold_count[0]
worst_item  = items[0]
for i in range(1, len(items)):    # start at 1 -- already have index 0
    # YOUR CODE: update worst_count and worst_item
    pass
print(f"Worst: {worst_item} ({worst_count})")

# Items selling > 25 portions
print("\nAbove 25:")
for i in range(len(items)):
    # YOUR CODE
    pass

print(f"Total portions: {sum(sold_count)}")

# %% [markdown]
# ### Exercise 2.17 -- while loop: order entry

# %%
# While loop that accepts orders until user types "done"
menu_items = [
    "Jollof Rice","Pounded Yam","Egusi Soup","Pepper Soup",
    "Spring Rolls","Chapman","Zobo","Fresh Juice",
    "Chin Chin","Puff Puff","Fried Plantain","Beef Suya"
]
order = []
print("Enter items one at a time. Type done to finish.")
while True:
    entry = input("Item: ").strip()
    if entry.lower() == "done":
        print("Order closed.")
        break
    if entry in menu_items:
        order.append(entry)
        print(f"  Added: {entry}")
    else:
        print(f"  Not on menu: {entry}")
print(f"Final order ({len(order)} items): {order}")

# %% [markdown]
# ---
# ## FRIDAY -- The Friday Build
# ---

# %% [markdown]
# ### Step 1 -- Data (do not change)

# %%
menu_items = [
    "Jollof Rice","Pounded Yam","Egusi Soup","Pepper Soup",
    "Spring Rolls","Chapman","Zobo","Fresh Juice",
    "Chin Chin","Puff Puff","Fried Plantain","Beef Suya"
]
prices = [1800, 2200, 1500, 1200, 900, 600, 400, 700, 500, 450, 800, 1100]
incoming_orders = [
    ("Jollof Rice",2), ("Chapman",4), ("Pizza",1), ("Pounded Yam",1),
    ("Beef Suya",3), ("Pepper Soup",2), ("Fresh Juice",5), ("Zobo",2),
    ("Puff Puff",6), ("Burger",2), ("Egusi Soup",1), ("Fried Plantain",3),
]
print(f"Menu: {len(menu_items)} items | Orders: {len(incoming_orders)}")

# %% [markdown]
# ### Step 2 -- Initialise accumulators (BEFORE the loop)

# %%
accepted_orders  = []    # accepted order details
rejected_items   = []    # items not on menu
total_revenue    = 0     # running total revenue
total_items_sold = 0     # running total portions
print("Accumulators ready.")

# %% [markdown]
# ### Step 3 -- Processing loop

# %%
print("=" * 58)
print("  PROCESSING ORDERS...")
print("=" * 58)
for item_name, quantity in incoming_orders:
    if item_name in menu_items:
        item_index = menu_items.index(item_name)
        unit_price = ___________          # prices[item_index]
        subtotal   = ___________          # unit_price * quantity
        if subtotal >= 8000:
            discount_rate = 0.15;  tier = "Gold"
        elif subtotal >= 4000:
            discount_rate = 0.10;  tier = "Silver"
        elif subtotal >= 2000:
            discount_rate = 0.05;  tier = "Bronze"
        else:
            discount_rate = 0.0;   tier = "Standard"
        discount_amount = subtotal * discount_rate
        final_price     = ___________     # subtotal - discount_amount
        total_revenue    += ___________   # final_price
        total_items_sold += ___________   # quantity
        accepted_orders.append({
            "item":item_name,"qty":quantity,"unit":unit_price,
            "subtotal":subtotal,"tier":tier,
            "discount":discount_amount,"total":final_price
        })
        print(f"  ACCEPTED  {item_name:<20} x{quantity}  N{final_price:>8,.2f}  [{tier}]")
    else:
        rejected_items.append(item_name)
        print(f"  REJECTED  {item_name:<20} -- not on menu")

# %% [markdown]
# ### Step 4 -- Report

# %%
print()
print("=" * 58)
print("  THE GOLDEN FORK - DAILY ORDER REPORT")
print("=" * 58)
print(f"  Orders received: {len(incoming_orders):>6}")
print(f"  Orders accepted: {len(accepted_orders):>6}")
print(f"  Orders rejected: {len(rejected_items):>6}")
print(f"  Portions sold:   {total_items_sold:>6,}")
print(f"\n  Total revenue:   N{total_revenue:>10,.2f}")
if len(accepted_orders) > 0:
    avg = ___________               # total_revenue / len(accepted_orders)
    print(f"  Avg order value: N{avg:>10,.2f}")
if rejected_items:
    print("\n  REJECTED ITEMS")
    for item in rejected_items:
        print(f"    - {item}")
# -- GIVEN SECTION -- uses dictionaries (Week 3 topic) -- read, do not modify --
print("\n  DISCOUNT TIER BREAKDOWN")
tier_counts = {}
for order in accepted_orders:
    t = order["tier"]
    if t not in tier_counts:
        tier_counts[t] = 0
    tier_counts[t] += 1
for tier, count in sorted(tier_counts.items()):
    print(f"    {tier:<12} {count:>3} order(s)")
print()
print("=" * 58)
print("  Report by Meridian Consulting")
print("=" * 58)

# %% [markdown]
# ### Extension challenges

# %%
# Challenge A: Add VAT_RATE = 0.075 -- apply after discount
# Challenge B: Find best-selling item (most portions) -- add to report
# Challenge C: Replace incoming_orders with while True / input() loop
# YOUR CODE HERE

# %% [markdown]
# ## ✅ What You Can Do After This Week
#
# By the end of this week, you can:
# - Store ordered collections of data in lists and access any element by position
# - Process every item in a dataset using a `for` loop — without writing repetitive code
# - Use conditional logic to classify transactions, apply discounts, and flag anomalies
# - Combine loops and conditions to produce filtered summaries from raw data
# - Write list comprehensions to transform data in a single readable line
#
# *Add `week2_lists_loops.ipynb` to your internship portfolio.*

# %% [markdown]
# ---
#
# ## Week 2 Checklist
#
# - [ ] week2_lists_loops.ipynb saved
# - [ ] Mon 2.1-2.4: lists, indexing, slicing (stop is excluded), membership
# - [ ] Tue 2.5-2.7: list methods, sort vs sorted, parallel lists
# - [ ] Wed 2.8-2.11: tiers, opening hours, stepped delivery fee, indentation
# - [ ] Thu 2.12-2.17: table, weekly, availability, order loop, best/worst, while
# - [ ] Fri Steps 2-4: order processor complete
# - [ ] One extension challenge attempted
# - [ ] Can explain: zero-based index, stop-excluded slice, accumulator, for vs while, break

# %% [markdown]
# ---
# ## Week 2 Complete
# Next: `week3/week3_*_STARTER.ipynb`
#
# ---
# *The Python Internship | Meridian Consulting*
